# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import time
import multiprocessing

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix, r2_score, mean_squared_error

# %%
df = pd.read_csv('Train_Data.csv')
df
# Out:
#        duration protocoltype      service flag  srcbytes  dstbytes  land  \
# 0             0          tcp  netbios_dgm  REJ         0         0     0
# 1             0          tcp         smtp   SF      1239       400     0
# 2             0          tcp         http   SF       222       945     0
# 3             0          tcp         http   SF       235      1380     0
# 4             0          tcp    uucp_path  REJ         0         0     0
# ...         ...          ...          ...  ...       ...       ...   ...
# 86840         0          tcp         http   SF       216       674     0
# 86841         0          tcp         http   SF       368      1725     0
# 86842        28          tcp          ftp   SF      1483      4152     0
# 86843         0          tcp         smtp   SF      1679       385     0
# 86844     11343          tcp       telnet   SF      3396     16694     0
#
#        wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# ...

# %%
df.shape
# Out:
# (86845, 43)

# %%
df.replace({'normal': 0, 'neptune': 1}, inplace=True)
df
# Out:
#        duration  protocoltype  service  flag  srcbytes  dstbytes  land  \
# 0             0             1       33     1         0         0     0
# 1             0             1       49     8      1239       400     0
# 2             0             1       22     8       222       945     0
# 3             0             1       22     8       235      1380     0
# 4             0             1       62     1         0         0     0
# ...         ...           ...      ...   ...       ...       ...   ...
# 86840         0             1       22     8       216       674     0
# 86841         0             1       22     8       368      1725     0
# 86842        28             1       18     8      1483      4152     0
# 86843         0             1       49     8      1679       385     0
# 86844     11343             1       55     8      3396     16694     0
#
#        wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# ...

# %%
le = LabelEncoder()
df['protocoltype'] = le.fit_transform(df['protocoltype'])
df['service'] = le.fit_transform(df['service'])
df['flag'] = le.fit_transform(df['flag'])
df
# Out:
#        duration  protocoltype  service  flag  srcbytes  dstbytes  land  \
# 0             0             1       33     1         0         0     0
# 1             0             1       49     8      1239       400     0
# 2             0             1       22     8       222       945     0
# 3             0             1       22     8       235      1380     0
# 4             0             1       62     1         0         0     0
# ...         ...           ...      ...   ...       ...       ...   ...
# 86840         0             1       22     8       216       674     0
# 86841         0             1       22     8       368      1725     0
# 86842        28             1       18     8      1483      4152     0
# 86843         0             1       49     8      1679       385     0
# 86844     11343             1       55     8      3396     16694     0
#
#        wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# ...

# %%
train = df.drop(['attack'],axis=1)
target = df['attack']

# %%
adb = AdaBoostClassifier(n_estimators=1000, random_state=0)
adb.fit(train, target)
# Out:
# AdaBoostClassifier(n_estimators=1000, random_state=0)

# %%
test = pd.read_csv('Test_Data.csv')
test.head()
# Out:
#    duration protocoltype  service flag  srcbytes  dstbytes  land  \
# 0         0          tcp      mtp  REJ         0         0     0
# 1         0          tcp     http   SF       199      1721     0
# 2         0          tcp  discard   S0         0         0     0
# 3         0          tcp   telnet   S0         0         0     0
# 4         0          tcp     exec   S0         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsrvcount  dsthostsamesrvrate  \
# 0              0       0    0  ...                7                0.03
# 1              0       0    0  ...              255                1.00
# 2              0       0    0  ...               14                0.05
# 3              0       0    0  ...                2                0.01
# 4              0       0    0  ...               16                0.06
#
#    dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# ...

# %%
le = LabelEncoder()
test['protocoltype'] = le.fit_transform(test['protocoltype'])
test['service'] = le.fit_transform(test['service'])
test['flag'] = le.fit_transform(test['flag'])
test.head()
# Out:
#    duration  protocoltype  service  flag  srcbytes  dstbytes  land  \
# 0         0             1       31     1         0         0     0
# 1         0             1       22     8       199      1721     0
# 2         0             1        9     4         0         0     0
# 3         0             1       55     4         0         0     0
# 4         0             1       16     4         0         0     0
#
#    wrongfragment  urgent  hot  ...  dsthostsrvcount  dsthostsamesrvrate  \
# 0              0       0    0  ...                7                0.03
# 1              0       0    0  ...              255                1.00
# 2              0       0    0  ...               14                0.05
# 3              0       0    0  ...                2                0.01
# 4              0       0    0  ...               16                0.06
#
#    dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# ...

# %%
output = adb.predict(test)

# %%
output
# Out:
# array([1, 0, 1, ..., 1, 0, 1], dtype=int64)

# %%
result = pd.DataFrame(output.T, columns=['attack'])

# %%
result.head()
# Out:
#    attack
# 0       1
# 1       0
# 2       1
# 3       1
# 4       1

# %%
result.to_csv('Results.csv')
